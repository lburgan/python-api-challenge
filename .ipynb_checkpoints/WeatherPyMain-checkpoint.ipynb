# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
# Impor the OpenWeatherMap API key
from apikeys import weather_api

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 562
# ['bilibino', 'motygino', 'harstad', 'adamstown', 'port-aux-francais', 'arraial do cabo', 'wuyo', 'howard springs', 'harper', 'rabigh', 'rikaze', 'port-gentil', 'gisborne', 'mount pearl', 'gamay', 'ushuaia', 'six-fours-les-plages', 'dryden', 'iqaluit', 'puerto natales', 'papao', 'senanga', 'yangor', 'aasiaat', 'blackmans bay', 'grytviken', 'zavitinsk', 'waitangi', 'el granada', 'stanley', 'magadan', 'temple', 'karlino', 'lom sak', 'hermanus', 'ancud', 'coahuayana de hidalgo', 'sao joao da barra', 'muang phonsavan', 'avarua', 'kodiak', 'dordrecht', 'edinburgh of the seven seas', 'matthew town', 'caleta de carquin', 'greymouth', 'takoradi', 'cabo san lucas', 'nieves', 'thunder bay', 'tiksi', 'yarkovo', 'arfoud', 'bandar abbas', 'savur', 'talnakh', 'tondano', 'afaahiti', 'kuqa', 'dabat', 'puerto ayacucho', 'worland', 'saint-leu', 'kavieng', 'odacho-oda', 'nemuro', 'tura', 'leava', 'vilyuchinsk', 'pratt', 'holualoa', 'domna', 'albany', 'itoman', 'hithadhoo', 'margaret river', 'gao', 'papatowai', 'bredasdorp', 'kargasok', 'bethel', 'ribeira grande', 'enriquillo', 'el transito', 'pankrushikha', 'thompson', "'ohonua", 'berdigestyakh', 'novyy urengoy', 'iskateley', 'orsa', 'nova sintra', 'acapulco de juarez', 'brak', 'mount gambier', 'port douglas', 'ust-nera', 'nizhnyaya tavda', 'kayangel', 'sona', 'chonchi', 'alofi', 'anadyr', 'taoudenni', 'yellowknife', 'georgetown', 'sisimiut', 'zhezqazghan', 'saint-joseph', 'petropavlovsk-kamchatsky', 'puerto san carlos', 'hinesville', 'constantia', 'khorramabad', 'vejen', 'bikenibeu village', 'kismayo', 'niksar', 'ta`u', 'shengli', 'ola', 'fuerte olimpo', 'praia da vitoria', 'pisco', 'taiohae', 'escarcega', 'lebu', 'chapadinha', 'ilulissat', 'olonkinbyen', 'hawaiian paradise park', 'qaqortoq', 'utrik', 'horta', 'west island', 'katsuura', 'longyearbyen', 'kerikeri', 'port elizabeth', 'maumere', 'hamilton', 'kolwezi', 'benghazi', 'port mathurin', 'kashary', 'saint johnsbury', 'namibe', 'tamanrasset', 'flying fish cove', 'kiruna', 'prado', 'ambovombe', 'farafenni', 'college', 'mili', 'pacific grove', 'amga', 'wailua homesteads', 'sao vicente', 'mar del plata', 'troitskoye', 'luganville', 'fale old settlement', 'tralee', 'christchurch', 'malango', 'port glaud', 'kuala tungkal', 'jacksonville beach', 'puerto ayora', 'alaghsas', 'ishqoshim', 'udachny', 'aykhal', 'fuvahmulah', 'wewak', 'madaoua', 'chibougamau', 'southside', 'zhangzhou', 'lazaro cardenas', 'westport', 'ketchikan', 'labytnangi', 'shahba', 'castillos', 'withernsea', 'lompoc', 'toliara', 'tabas', 'pontevedra', 'badger', 'timbuktu', 'kiffa', 'sosua', 'elverum', 'haiku-pauwela', 'lamu', 'chegdomyn', 'mata-utu', 'grand falls-windsor', 'invercargill', 'whitehorse', 'mount isa', 'guerrero negro', 'as sulayyil', 'maitum', 'tolanaro', 'san antonio de pale', 'borogontsy', 'marsabit', 'olyokminsk', 'visakhapatnam', 'ilebo', 'cheremukhovo', 'la passe', "roshal'", 'cova figueira', 'broken hill', 'tigre', 'nefta', 'vorgashor', 'uturoa', "st. john's", 'rio grande', 'kievka', 'tazovsky', 'namtsy', 'balod', 'east london', 'alakurtti', 'alice springs', 'punta arenas', 'rio branco do sul', "nar'yan-mar", 'parfino', 'sawakin', 'douglas', 'pandan', 'kruisfontein', 'katsuren-haebaru', 'vadso', 'manicore', 'margate', 'syumsi', "nuku'alofa", 'tha khanon', 'xinmin', 'nabire', 'vikhorevka', 'tranovaho', 'moab', 'linxia chengguanzhen', 'zhangye', 'hengchun', 'puerto baquerizo moreno', 'tateyama', 'dudinka', 'saint-philippe', 'bac lieu', 'saipan', 'okondja', 'aldinga beach', "al 'alamayn", 'suva', 'tindouf', 'traverse city', 'kulia village', 'omdurman', 'pestravka', 'flin flon', 'trondheim', 'enewetak', 'brandon', 'atafu village', "arkhangel'sk", 'peace river', 'buka', 'gamboula', 'broome', 'zemio', 'kailua-kona', 'kavaratti', 'dumas', 'opuwo', 'jamestown', 'barentu', 'carutapera', 'yanykurgan', 'trairi', 'cidreira', 'yunak', 'tela', 'san matias', 'ploneour-lanvern', 'yankton', 'geraldton', 'muisne', 'crane', 'vila franca do campo', 'vilyuysk', 'energetik', 'ocos',  ...

# %%
practice_url = "https://api.openweathermap.org/data/2.5/weather?q=bilibino&appid=" + weather_api + "&units=metric"
practice = requests.get(practice_url).json()
pprint(practice)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 68.0546, 'lon': 166.4372},
#  'dt': 1682379913,
#  'id': 2126682,
#  'main': {'feels_like': -5.11,
#           'grnd_level': 985,
#           'humidity': 54,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': -3.15,
#           'temp_max': -3.15,
#           'temp_min': -3.15},
#  'name': 'Bilibino',
#  'sys': {'country': 'RU', 'sunrise': 1682353310, 'sunset': 1682414553},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 95, 'gust': 1.43, 'speed': 1.37}}

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city + "&appid=" + weather_api + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date =city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | motygino
# Processing Record 3 of Set 1 | harstad
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | wuyo
# Processing Record 8 of Set 1 | howard springs
# Processing Record 9 of Set 1 | harper
# Processing Record 10 of Set 1 | rabigh
# Processing Record 11 of Set 1 | rikaze
# Processing Record 12 of Set 1 | port-gentil
# Processing Record 13 of Set 1 | gisborne
# Processing Record 14 of Set 1 | mount pearl
# Processing Record 15 of Set 1 | gamay
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | six-fours-les-plages
# Processing Record 18 of Set 1 | dryden
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | puerto natales
# Processing Record 21 of Set 1 | papao
# Processing Record 22 of Set 1 | senanga
# Processing Record 23 of Set 1 | yangor
# City not found. Skipping...
# Processing Record 24 of Set 1 | aasiaat
# Processing Record 25 of Set 1 | blackmans bay
# Processing Record 26 of Set 1 | grytviken
# Processing Record 27 of Set 1 | zavitinsk
# Processing Record 28 of Set 1 | waitangi
# Processing Record 29 of Set 1 | el granada
# Processing Record 30 of Set 1 | stanley
# Processing Record 31 of Set 1 | magadan
# Processing Record 32 of Set 1 | temple
# Processing Record 33 of Set 1 | karlino
# Processing Record 34 of Set 1 | lom sak
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | coahuayana de hidalgo
# Processing Record 38 of Set 1 | sao joao da barra
# Processing Record 39 of Set 1 | muang phonsavan
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | dordrecht
# Processing Record 43 of Set 1 | edinburgh of the seven seas
# Processing Record 44 of Set 1 | matthew town
# Processing Record 45 of Set 1 | caleta de carquin
# Processing Record 46 of Set 1 | greymouth
# Processing Record 47 of Set 1 | takoradi
# Processing Record 48 of Set 1 | cabo san lucas
# Processing Record 49 of Set 1 | nieves
# Processing Record 50 of Set 1 | thunder bay
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | yarkovo
# Processing Record 2 of Set 2 | arfoud
# Processing Record 3 of Set 2 | bandar abbas
# Processing Record 4 of Set 2 | savur
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | tondano
# Processing Record 7 of Set 2 | afaahiti
# Processing Record 8 of Set 2 | kuqa
# Processing Record 9 of Set 2 | dabat
# Processing Record 10 of Set 2 | puerto ayacucho
# Processing Record 11 of Set 2 | worland
# Processing Record 12 of Set 2 | saint-leu
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | odacho-oda
# Processing Record 15 of Set 2 | nemuro
# Processing Record 16 of Set 2 | tura
# Processing Record 17 of Set 2 | leava
# Processing Record 18 of Set 2 | vilyuchinsk
# Processing Record 19 of Set 2 | pratt
# Processing Record 20 of Set 2 | holualoa
# Processing Record 21 of Set 2 | domna
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | itoman
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | margaret river
# Processing Record 26 of Set 2 | gao
# Processing Record 27 of Set 2 | papatowai
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | kargasok
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | enriquillo
# Processing Record 33 of Set 2 | el transito
# Processing Record 34 of Set 2 | pankrushikha
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 37 of Set 2 | berdigestyakh
# Processing Record 38 of Set 2 | novyy urengoy
# Processing Record 39 of Set 2 | iskateley
# Processing Record 40 of Set 2 | orsa
# Processing Record 41 of Set 2 | nova sintra
# Processing Record 42 of Set 2 | acapulco de juarez
# Processing Record 43 of Set 2 | brak
# Processing Record 44 of Set 2 | mount gambier
# Processing Record 45 of Set 2 | port douglas
# Processing Record 46 of Set 2 | ust-nera
# Processing Record 47 of Set 2 | nizhnyaya tavda
# Processing Record 48 of Set 2 | kayangel
# Processing Record 49 of Set 2 | sona
# Processing Record 0 of Set 3 | chonchi
# Processing Record 1 of Set 3 | alofi
# Processing Record 2 of Set 3 | anadyr
# Processing Record 3 of Set 3 | taoudenni
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | sisimiut
# Processing Record 7 of Set 3 | zhezqazghan
# Processing Record 8 of Set 3 | saint-joseph
# Processing Record 9 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 11 of Set 3 | hinesville
# Processing Record 12 of Set 3 | constantia
# Processing Record 13 of Set 3 | khorramabad
# Processing Record 14 of Set 3 | vejen
# Processing Record 15 of Set 3 | bikenibeu village
# Processing Record 16 of Set 3 | kismayo
# Processing Record 17 of Set 3 | niksar
# Processing Record 18 of Set 3 | ta`u
# Processing Record 19 of Set 3 | shengli
# Processing Record 20 of Set 3 | ola
# Processing Record 21 of Set 3 | fuerte olimpo
# Processing Record 22 of Set 3 | praia da vitoria
# Processing Record 23 of Set 3 | pisco
# Processing Record 24 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 3 | escarcega
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | chapadinha
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | olonkinbyen
# Processing Record 30 of Set 3 | hawaiian paradise park
# Processing Record 31 of Set 3 | qaqortoq
# Processing Record 32 of Set 3 | utrik
# Processing Record 33 of Set 3 | horta
# Processing Record 34 of Set 3 | west island
# Processing Record 35 of Set 3 | katsuura
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | kerikeri
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | maumere
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | kolwezi
# Processing Record 42 of Set 3 | benghazi
# Processing Record 43 of Set 3 | port mathurin
# Processing Record 44 of Set 3 | kashary
# Processing Record 45 of Set 3 | saint johnsbury
# Processing Record 46 of Set 3 | namibe
# Processing Record 47 of Set 3 | tamanrasset
# Processing Record 48 of Set 3 | flying fish cove
# Processing Record 49 of Set 3 | kiruna
# Processing Record 0 of Set 4 | prado
# Processing Record 1 of Set 4 | ambovombe
# Processing Record 2 of Set 4 | farafenni
# Processing Record 3 of Set 4 | college
# Processing Record 4 of Set 4 | mili
# Processing Record 5 of Set 4 | pacific grove
# Processing Record 6 of Set 4 | amga
# Processing Record 7 of Set 4 | wailua homesteads
# Processing Record 8 of Set 4 | sao vicente
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | troitskoye
# Processing Record 11 of Set 4 | luganville
# Processing Record 12 of Set 4 | fale old settlement
# Processing Record 13 of Set 4 | tralee
# Processing Record 14 of Set 4 | christchurch
# Processing Record 15 of Set 4 | malango
# Processing Record 16 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 17 of Set 4 | kuala tungkal
# Processing Record 18 of Set 4 | jacksonville beach
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | alaghsas
# Processing Record 21 of Set 4 | ishqoshim
# Processing Record 22 of Set 4 | udachny
# Processing Record 23 of Set 4 | aykhal
# Processing Record 24 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 25 of Set 4 | wewak
# Processing Record 26 of Set 4 | madaoua
# Processing Record 27 of Set 4 | chibougamau
# Processing Record 28 of Set 4 | southside
# Processing Record 29 of Set 4 | zhangzhou
# Processing Record 30 of Set 4 | lazaro cardenas
# Processing Record 31 of Set 4 | westport
# Processing Record 32 of Set 4 | ketchikan
# Processing Record 33 of Set 4 | labytnangi
# Processing Record 34 of Set 4 | shahba
# Processing Record 35 of Set 4 | castillos
# Processing Record 36 of Set 4 | withernsea
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | toliara
# Processing Record 39 of Set 4 | tabas
# Processing Record 40 of Set 4 | pontevedra
# Processing Record 41 of Set 4 | badger
# Processing Record 42 of Set 4 | timbuktu
# Processing Record 43 of Set 4 | kiffa
# Processing Record 44 of Set 4 | sosua
# Processing Record 45 of Set 4 | elverum
# Processing Record 46 of Set 4 | haiku-pauwela
# Processing Record 47 of Set 4 | lamu
# Processing Record 48 of Set 4 | chegdomyn
# Processing Record 49 of Set 4 | mata-utu
# Processing Record 0 of Set 5 | grand falls-windsor
# Processing Record 1 of Set 5 | invercargill
# Processing Record 2 of Set 5 | whitehorse
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | guerrero negro
# Processing Record 5 of Set 5 | as sulayyil
# Processing Record 6 of Set 5 | maitum
# Processing Record 7 of Set 5 | tolanaro
# Processing Record 8 of Set 5 | san antonio de pale
# Processing Record 9 of Set 5 | borogontsy
# Processing Record 10 of Set 5 | marsabit
# Processing Record 11 of Set 5 | olyokminsk
# Processing Record 12 of Set 5 | visakhapatnam
# Processing Record 13 of Set 5 | ilebo
# Processing Record 14 of Set 5 | cheremukhovo
# Processing Record 15 of Set 5 | la passe
# Processing Record 16 of Set 5 | roshal'
# Processing Record 17 of Set 5 | cova figueira
# Processing Record 18 of Set 5 | broken hill
# Processing Record 19 of Set 5 | tigre
# Processing Record 20 of Set 5 | nefta
# Processing Record 21 of Set 5 | vorgashor
# Processing Record 22 of Set 5 | uturoa
# Processing Record 23 of Set 5 | st. john's
# Processing Record 24 of Set 5 | rio grande
# Processing Record 25 of Set 5 | kievka
# Processing Record 26 of Set 5 | tazovsky
# Processing Record 27 of Set 5 | namtsy
# Processing Record 28 of Set 5 | balod
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | alakurtti
# Processing Record 31 of Set 5 | alice springs
# Processing Record 32 of Set 5 | punta arenas
# Processing Record 33 of Set 5 | rio branco do sul
# Processing Record 34 of Set 5 | nar'yan-mar
# Processing Record 35 of Set 5 | parfino
# Processing Record 36 of Set 5 | sawakin
# Processing Record 37 of Set 5 | douglas
# Processing Record 38 of Set 5 | pandan
# Processing Record 39 of Set 5 | kruisfontein
# Processing Record 40 of Set 5 | katsuren-haebaru
# Processing Record 41 of Set 5 | vadso
# Processing Record 42 of Set 5 | manicore
# Processing Record 43 of Set 5 | margate
# Processing Record 44 of Set 5 | syumsi
# Processing Record 45 of Set 5 | nuku'alofa
# Processing Record 46 of Set 5 | tha khanon
# Processing Record 47 of Set 5 | xinmin
# Processing Record 48 of Set 5 | nabire
# Processing Record 49 of Set 5 | vikhorevka
# Processing Record 0 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 1 of Set 6 | moab
# Processing Record 2 of Set 6 | linxia chengguanzhen
# Processing Record 3 of Set 6 | zhangye
# Processing Record 4 of Set 6 | hengchun
# Processing Record 5 of Set 6 | puerto baquerizo moreno
# Processing Record 6 of Set 6 | tateyama
# Processing Record 7 of Set 6 | dudinka
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | bac lieu
# Processing Record 10 of Set 6 | saipan
# Processing Record 11 of Set 6 | okondja
# Processing Record 12 of Set 6 | aldinga beach
# Processing Record 13 of Set 6 | al 'alamayn
# City not found. Skipping...
# Processing Record 14 of Set 6 | suva
# Processing Record 15 of Set 6 | tindouf
# Processing Record 16 of Set 6 | traverse city
# Processing Record 17 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 18 of Set 6 | omdurman
# Processing Record 19 of Set 6 | pestravka
# Processing Record 20 of Set 6 | flin flon
# Processing Record 21 of Set 6 | trondheim
# Processing Record 22 of Set 6 | enewetak
# Processing Record 23 of Set 6 | brandon
# Processing Record 24 of Set 6 | atafu village
# Processing Record 25 of Set 6 | arkhangel'sk
# Processing Record 26 of Set 6 | peace river
# Processing Record 27 of Set 6 | buka
# Processing Record 28 of Set 6 | gamboula
# Processing Record 29 of Set 6 | broome
# Processing Record 30 of Set 6 | zemio
# Processing Record 31 of Set 6 | kailua-kona
# Processing Record 32 of Set 6 | kavaratti
# Processing Record 33 of Set 6 | dumas
# Processing Record 34 of Set 6 | opuwo
# Processing Record 35 of Set 6 | jamestown
# Processing Record 36 of Set 6 | barentu
# Processing Record 37 of Set 6 | carutapera
# Processing Record 38 of Set 6 | yanykurgan
# Processing Record 39 of Set 6 | trairi
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | yunak
# Processing Record 42 of Set 6 | tela
# Processing Record 43 of Set 6 | san matias
# Processing Record 44 of Set 6 | ploneour-lanvern
# Processing Record 45 of Set 6 | yankton
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | muisne
# Processing Record 48 of Set 6 | crane
# Processing Record 49 of Set 6 | vila franca do campo
# Processing Record 0 of Set 7 | vilyuysk
# Processing Record 1 of Set 7 | energetik
# Processing Record 2 of Set 7 | ocos
# Processing Record 3 of Set 7 | brezovica
# Processing Record 4 of Set 7 | lihue
# Processing Record 5 of Set 7 | hadibu
# Processing Record 6 of Set 7 | santa ana
# Processing Record 7 of Set 7 | mancio lima
# Processing Record 8 of Set 7 | progreso
# Processing Record 9 of Set 7 | bubaque
# Processing Record 10 of Set 7 | oistins
# Processing Record 11 of Set 7 | happy valley-goose bay
# Processing Record 12 of Set 7 | coquimbo
# Processing Record 13 of Set 7 | dunedin
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | nantucket
# Processing Record 16 of Set 7 | colonia
# Processing Record 17 of Set 7 | bardai
# Processing Record 18 of Set 7 | gastonia
# Processing Record 19 of Set 7 | vrangel'
# Processing Record 20 of Set 7 | luderitz
# Processing Record 21 of Set 7 | isafjordur
# Processing Record 22 of Set 7 | tazacorte
# Processing Record 23 of Set 7 | machali
# Processing Record 24 of Set 7 | mariehamn
# Processing Record 25 of Set 7 | arno
# Processing Record 26 of Set 7 | nadym
# Processing Record 27 of Set 7 | rumphi
# Processing Record 28 of Set 7 | santa eularia des riu
# Processing Record 29 of Set 7 | sechura
# Processing Record 30 of Set 7 | kone
# Processing Record 31 of Set 7 | al jawf
# Processing Record 32 of Set 7 | istaravshan
# Processing Record 33 of Set 7 | dibba al-hisn
# Processing Record 34 of Set 7 | kalmunai
# Processing Record 35 of Set 7 | kokshetau
# Processing Record 36 of Set 7 | imbituba
# Processing Record 37 of Set 7 | prince george
# Processing Record 38 of Set 7 | alesund
# Processing Record 39 of Set 7 | altamira
# Processing Record 40 of Set 7 | oyem
# Processing Record 41 of Set 7 | la palma
# Processing Record 42 of Set 7 | newman
# Processing Record 43 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 44 of Set 7 | plottier
# Processing Record 45 of Set 7 | smithers
# Processing Record 46 of Set 7 | puerto deseado
# Processing Record 47 of Set 7 | san patricio
# Processing Record 48 of Set 7 | sabang
# Processing Record 49 of Set 7 | keetmanshoop
# Processing Record 0 of Set 8 | mogadishu
# Processing Record 1 of Set 8 | sullivan
# Processing Record 2 of Set 8 | kangding
# Processing Record 3 of Set 8 | wenchang
# Processing Record 4 of Set 8 | lamar
# Processing Record 5 of Set 8 | klyuchi
# Processing Record 6 of Set 8 | sosnovka
# Processing Record 7 of Set 8 | tofol
# Processing Record 8 of Set 8 | chukhloma
# Processing Record 9 of Set 8 | gadzhiyevo
# Processing Record 10 of Set 8 | new norfolk
# Processing Record 11 of Set 8 | amursk
# Processing Record 12 of Set 8 | quellon
# Processing Record 13 of Set 8 | donggongon
# Processing Record 14 of Set 8 | bereket
# Processing Record 15 of Set 8 | egilsstadir
# Processing Record 16 of Set 8 | sale
# Processing Record 17 of Set 8 | fort mcmurray
# Processing Record 18 of Set 8 | porto velho
# Processing Record 19 of Set 8 | ibiapina
# Processing Record 20 of Set 8 | isiro
# Processing Record 21 of Set 8 | port lincoln
# Processing Record 22 of Set 8 | uyuni
# Processing Record 23 of Set 8 | diu
# Processing Record 24 of Set 8 | carbonear
# Processing Record 25 of Set 8 | trincomalee
# Processing Record 26 of Set 8 | laayoune plage
# City not found. Skipping...
# Processing Record 27 of Set 8 | i-n-salah
# Processing Record 28 of Set 8 | zyryanovsk
# Processing Record 29 of Set 8 | surab
# Processing Record 30 of Set 8 | bonthe
# Processing Record 31 of Set 8 | bamboo flat
# Processing Record 32 of Set 8 | greenville
# Processing Record 33 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 34 of Set 8 | merizo village
# Processing Record 35 of Set 8 | sault ste. marie
# Processing Record 36 of Set 8 | zarah sharan
# Processing Record 37 of Set 8 | nogliki
# Processing Record 38 of Set 8 | changji
# Processing Record 39 of Set 8 | prince rupert
# Processing Record 40 of Set 8 | rupert
# Processing Record 41 of Set 8 | andalgala
# Processing Record 42 of Set 8 | tutayev
# Processing Record 43 of Set 8 | boda
# Processing Record 44 of Set 8 | kapa'a
# Processing Record 45 of Set 8 | ugoofaaru
# Processing Record 46 of Set 8 | bel ombre
# Processing Record 47 of Set 8 | kimbe
# Processing Record 48 of Set 8 | nagqu
# Processing Record 49 of Set 8 | cockburn town
# Processing Record 0 of Set 9 | sao felix do xingu
# Processing Record 1 of Set 9 | urangan
# Processing Record 2 of Set 9 | fortuna
# Processing Record 3 of Set 9 | wynyard
# Processing Record 4 of Set 9 | taltal
# Processing Record 5 of Set 9 | cuatro cienegas de carranza
# Processing Record 6 of Set 9 | balad
# Processing Record 7 of Set 9 | yarmouth
# Processing Record 8 of Set 9 | vokhtoga
# Processing Record 9 of Set 9 | sitka
# Processing Record 10 of Set 9 | dean funes
# Processing Record 11 of Set 9 | nikolayevsk-on-amure
# Processing Record 12 of Set 9 | ulsteinvik
# Processing Record 13 of Set 9 | port hedland
# Processing Record 14 of Set 9 | bitkine
# Processing Record 15 of Set 9 | vila velha
# Processing Record 16 of Set 9 | dadhar
# Processing Record 17 of Set 9 | taro
# Processing Record 18 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 19 of Set 9 | luau
# Processing Record 20 of Set 9 | port macquarie
# Processing Record 21 of Set 9 | labrador city
# Processing Record 22 of Set 9 | rovinj
# Processing Record 23 of Set 9 | az zulfi
# Processing Record 24 of Set 9 | neufchateau
# Processing Record 25 of Set 9 | sergeyevka
# Processing Record 26 of Set 9 | pundong
# Processing Record 27 of Set 9 | al bawiti
# Processing Record 28 of Set 9 | nangen
# Processing Record 29 of Set 9 | rongelap
# Processing Record 30 of Set 9 | smithfield
# Processing Record 31 of Set 9 | taghazout
# Processing Record 32 of Set 9 | laguna
# Processing Record 33 of Set 9 | waingapu
# Processing Record 34 of Set 9 | marsh harbour
# Processing Record 35 of Set 9 | tshikapa
# Processing Record 36 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 37 of Set 9 | portland
# Processing Record 38 of Set 9 | callao
# Processing Record 39 of Set 9 | mascote
# Processing Record 40 of Set 9 | qamdo
# Processing Record 41 of Set 9 | nyurba
# Processing Record 42 of Set 9 | sandnessjoen
# Processing Record 43 of Set 9 | camana
# Processing Record 44 of Set 9 | semirom
# Processing Record 45 of Set 9 | lata
# Processing Record 46 of Set 9 | borongan
# Processing Record 47 of Set 9 | copainala
# Processing Record 48 of Set 9 | antalaha
# Processing Record 49 of Set 9 | moree
# Processing Record 0 of Set 10 | am timan
# Processing Record 1 of Set 10 | yaroslavskiy
# Processing Record 2 of Set 10 | franklin
# Processing Record 3 of Set 10 | okhotsk
# Processing Record 4 of Set 10 | hami
# Processing Record 5 of Set 10 | mahina
# Processing Record 6 of Set 10 | bandon
# Processing Record 7 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 8 of Set 10 | khanpur
# Processing Record 9 of Set 10 | port alfred
# Processing Record 10 of Set 10 | marquette
# Processing Record 11 of Set 10 | judenburg
# Processing Record 12 of Set 10 | west bay
# Processing Record 13 of Set 10 | kapuskasing
# Processing Record 14 of Set 10 | liman
# Processing Record 15 of Set 10 | manta
# Processing Record 16 of Set 10 | camocim
# Processing Record 17 of Set 10 | nadi
# Processing Record 18 of Set 10 | at taj
# Processing Record 19 of Set 10 | murzuq
# Processing Record 20 of Set 10 | valky
# Processing Record 21 of Set 10 | chernyshevskiy
# Processing Record 22 of Set 10 | nguigmi
# Processing Record 23 of Set 10 | al ghayzah
# Processing Record 24 of Set 10 | santiago de cao
# Processing Record 25 of Set 10 | palopo
# Processing Record 26 of Set 10 | hilo
# Processing Record 27 of Set 10 | jumla
# Processing Record 28 of Set 10 | arawa
# Processing Record 29 of Set 10 | puerto colombia
# Processing Record 30 of Set 10 | garcia
# Processing Record 31 of Set 10 | mountain home
# Processing Record 32 of Set 10 | santa terezinha
# City not found. Skipping...
# Processing Record 33 of Set 10 | harar
# Processing Record 34 of Set 10 | pariyapuram
# Processing Record 35 of Set 10 | ponta pora
# Processing Record 36 of Set 10 | mahmudabad
# Processing Record 37 of Set 10 | emerald
# Processing Record 38 of Set 10 | bangassou
# Processing Record 39 of Set 10 | fisterra
# Processing Record 40 of Set 10 | kihurio
# Processing Record 41 of Set 10 | yuzhno-kurilsk
# Processing Record 42 of Set 10 | kwale
# Processing Record 43 of Set 10 | urumqi
# Processing Record 44 of Set 10 | gorontalo
# Processing Record 45 of Set 10 | fada
# Processing Record 46 of Set 10 | nuuk
# Processing Record 47 of Set 10 | selfoss
# Processing Record 48 of Set 10 | xapuri
# Processing Record 49 of Set 10 | songea
# Processing Record 0 of Set 11 | illizi
# Processing Record 1 of Set 11 | ust'-ilimsk
# Processing Record 2 of Set 11 | montmagny
# Processing Record 3 of Set 11 | kaiyuan
# Processing Record 4 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 5 of Set 11 | kretinga
# Processing Record 6 of Set 11 | queenstown
# Processing Record 7 of Set 11 | malabar
# Processing Record 8 of Set 11 | ruidoso
# Processing Record 9 of Set 11 | kawalu
# Processing Record 10 of Set 11 | sao francisco de assis
# Processing Record 11 of Set 11 | esperantina
# Processing Record 12 of Set 11 | lembar
# City not found. Skipping...
# Processing Record 13 of Set 11 | kristiansund
# Processing Record 14 of Set 11 | santa elena de uairen
# Processing Record 15 of Set 11 | banda aceh
# Processing Record 16 of Set 11 | tabou
# Processing Record 17 of Set 11 | zayed city
# Processing Record 18 of Set 11 | acarau
# Processing Record 19 of Set 11 | baloda
# Processing Record 20 of Set 11 | marsa alam
# Processing Record 21 of Set 11 | rhinelander
# Processing Record 22 of Set 11 | sassandra
# Processing Record 23 of Set 11 | palmas
# Processing Record 24 of Set 11 | gizo
# Processing Record 25 of Set 11 | tupiza
# Processing Record 26 of Set 11 | tangalle
# Processing Record 27 of Set 11 | tinaan
# Processing Record 28 of Set 11 | ladario
# Processing Record 29 of Set 11 | gotsucho
# Processing Record 30 of Set 11 | pimentel
# Processing Record 31 of Set 11 | uzgen
# Processing Record 32 of Set 11 | orsk
# Processing Record 33 of Set 11 | port saint john's
# Processing Record 34 of Set 11 | novodvinsk
# Processing Record 35 of Set 11 | kilosa
# Processing Record 36 of Set 11 | manokwari
# Processing Record 37 of Set 11 | gavle
# Processing Record 38 of Set 11 | betio village
# Processing Record 39 of Set 11 | sur
# Processing Record 40 of Set 11 | khovd
# Processing Record 41 of Set 11 | saint-francois
# Processing Record 42 of Set 11 | muravlenko
# Processing Record 43 of Set 11 | zharkent
# Processing Record 44 of Set 11 | zeya
# Processing Record 45 of Set 11 | susuman
# Processing Record 46 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 47 of Set 11 | n'dalatando
# Processing Record 48 of Set 11 | sirte
# Processing Record 49 of Set 11 | suntar
# Processing Record 0 of Set 12 | sinabang
# Processing Record 1 of Set 12 | ratoath
# Processing Record 2 of Set 12 | santiago
# Processing Record 3 of Set 12 | shirgaon
# Processing Record 4 of Set 12 | atyashevo
# Processing Record 5 of Set 12 | beledweyne
# Processing Record 6 of Set 12 | villa del totoral
# Processing Record 7 of Set 12 | torghay
# Processing Record 8 of Set 12 | inari
# Processing Record 9 of Set 12 | shelton
# Processing Record 10 of Set 12 | biltine
# Processing Record 11 of Set 12 | ixtapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data, columns = ["City", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed",
                                                  "Country", "Date"])

# Show Record Count
city_data_df.count()
# Out:
# City          543
# Lat           543
# Lng           543
# Max Temp      543
# Humidity      543
# Cloudiness    543
# Wind Speed    543
# Country       543
# Date          543
# dtype: int64

# %%
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           bilibino  68.0546  166.4372     -3.15        54           0
# 1           motygino  58.1831   94.7592      2.08        89         100
# 2            harstad  68.7990   16.5293     -1.32        72           9
# 3          adamstown -25.0660 -130.1015     25.70        87          88
# 4  port-aux-francais -49.3500   70.2167      4.58        66          63
#
#    Wind Speed Country        Date
# 0        1.37      RU  1682379913
# 1        1.28      RU  1682380484
# 2        1.34      NO  1682380484
# 3        6.92      PN  1682380485
# 4        7.55      TF  1682380485

# %%
# Export the City_Data into a csv
city_data_df.to_csv("Output Data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("Output Data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 bilibino  68.0546  166.4372     -3.15        54           0
# 1                 motygino  58.1831   94.7592      2.08        89         100
# 2                  harstad  68.7990   16.5293     -1.32        72           9
# 3                adamstown -25.0660 -130.1015     25.70        87          88
# 4        port-aux-francais -49.3500   70.2167      4.58        66          63
#
#          Wind Speed Country        Date
# City_ID
# 0              1.37      RU  1682379913
# 1              1.28      RU  1682380484
# 2              1.34      NO  1682380484
# 3              6.92      PN  1682380485
# 4              7.55      TF  1682380485

# %% [markdown]
# ### Required Scatterplots

# %%
# Build scatter plot for latitude vs. temperature
lat = city_data_df["Lat"]
temp = city_data_df["Max Temp"]
plt.scatter(lat,temp, color = "cyan", alpha = .75, edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temp. (C)")
plt.title("City Latitute vs. Max Temperature (4/24/2023)")

# Save the figure
plt.savefig("Output Data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
lat = city_data_df["Lat"]
humidity = city_data_df["Humidity"]
plt.scatter(lat,humidity,color = "cyan", alpha = .75, edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Latitdude vs. Humidity (4/24/2023)")
# Save the figure
plt.savefig("Output Data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
lat = city_data_df["Lat"]
clouds = city_data_df["Cloudiness"]
plt.scatter(lat,clouds,color = "cyan", alpha = .75, edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs. Cloudiness (4/24/2023)")
# Save the figure
plt.savefig("Output Data/Fig3.png")

# Show plot
plt.show()
# Out:
# City_ID
# 0      68.0546
# 1      58.1831
# 2      68.7990
# 3     -25.0660
# 4     -49.3500
#         ...
# 538    49.6339
# 539    68.9060
# 540    41.3165
# 541    14.5333
# 542    20.7000
# Name: Lat, Length: 543, dtype: float64

# %%
# Build the scatter plots for latitude vs. wind speed
lat = city_data_df["Lat"]
wind = city_data_df["Wind Speed"]
plt.scatter(lat,wind,color = "cyan",alpha = .75, edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("Latitude vs. Wind Speed 4/24/2023")
# Save the figure
plt.savefig("Output Data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
# Define a function to create Linear Regression plots
def lin_reg(x,y):
    lm = linregress(x,y)
    slope = lm[0]
    intercept = lm[1]
    r = lm[2]
    predicted_y = slope*x + intercept
    eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    lin_plot = plt.scatter(x,y,color = "cyan", alpha = .75, edgecolor = "black")
    plt.plot(x,predicted_y, color = "red")
    #plt.annotate(eq,(-40,80), color = "red")
    #plt.xlabel(f"{x["Name"]}")
    #plt.ylabel(f"{y}")
    #plt.title(f"{x} vs {y}")
    return(lin_plot,print(f"The r-value is {r}"))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"]>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        bilibino  68.0546  166.4372     -3.15        54           0
# 1        motygino  58.1831   94.7592      2.08        89         100
# 2         harstad  68.7990   16.5293     -1.32        72           9
# 6            wuyo  10.3852   11.6968     26.69        60         100
# 8          harper   4.3750   -7.7169     27.28        84         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.37      RU  1682379913
# 1              1.28      RU  1682380484
# 2              1.34      NO  1682380484
# 6              1.04      NG  1682380486
# 8              2.79      LR  1682380487

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"]< 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                adamstown -25.0660 -130.1015     25.70        87          88
# 4        port-aux-francais -49.3500   70.2167      4.58        66          63
# 5          arraial do cabo -22.9661  -42.0278     21.98        83           0
# 7           howard springs -12.4970  131.0470     29.90        73          40
# 11             port-gentil  -0.7193    8.7815     27.98        89          20
#
#          Wind Speed Country        Date
# City_ID
# 3              6.92      PN  1682380485
# 4              7.55      TF  1682380485
# 5              0.00      BR  1682380464
# 7              4.78      AU  1682380487
# 11             1.54      GA  1682380489

# %%
## Temperature vs. Latitude

# %%
#Northern Hemisphere
lat = northern_hemi_df["Lat"]
temp = northern_hemi_df["Max Temp"]
lin_reg(lat,temp)
# Out:
# The r-value is -0.8919237676531268
# (<matplotlib.collections.PathCollection at 0x1d2dc357ee0>, None)

# %%
#Southern Hemisphere
lat = southern_hemi_df["Lat"]
temp = southern_hemi_df["Max Temp"]
lin_reg(lat,temp)
# Out:
# The r-value is 0.7262745941112134
# (<matplotlib.collections.PathCollection at 0x1d2dcc48f10>, None)

# %%
##Humidity vs. Latitude
